# %% [markdown]
# ## The Sparks Foundation

# %% [markdown]
# ### Task 3 : Exploratory Data Analysis - Retail

# %% [markdown]
# <i><b>Perform the Exploratory Data Analysis on dataset 'SampleSuperstore'</b></i>

# %% [markdown]
# <b>Submitted by: SUSMA R</b>

# %%
# Importing the required libraries in this notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings as wg
wg.filterwarnings('ignore')

# %% [markdown]
# <b> Import the dataset</b>

# %%
data=pd.read_csv("C:/Users/USER/Downloads/SampleSuperstore.csv")
print("The dataset imported successfully")
# Out:
# The dataset imported successfully

# %% [markdown]
# <b> Quick view about dataset</b>

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# <b> Check for null values</b>

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# <b> Find the dtypes in the dataset</b>

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# <b>Finding all the column names in the dataset</b>

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# <b>Check for duplicate elements</b>

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %%
# CORRELATION

data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
# Covariance

data.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %%
# Dropping of Postal code column

data=data.drop(columns=["Postal Code"],axis=1)

# %%
# Heat map on dataset

fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(data.cov(),annot=True)
plt.show()

# %% [markdown]
# ### Grouping the data

# %%
category_group = data.groupby(['Category','Sub-Category'])['Sales','Quantity','Profit'].mean().reset_index()
segment_group = data.groupby(['Segment'])['Sales','Quantity','Profit'].mean().reset_index()
region_group = data.groupby(['Region'])['Sales','Quantity','Profit'].mean().reset_index()
state_group = data.groupby(['State'])['Sales','Quantity','Profit'].mean().reset_index()
shipmode_group = data.groupby(['Ship Mode'])['Sales','Quantity','Profit'].mean().reset_index()

# %% [markdown]
# ### Category Wise

# %%
# Category types

# %%
data["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
data["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
# Sub Category

# %%
data["Sub-Category"].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
data["Sub-Category"].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
# Pie plot of Sub Category

plt.figure(figsize=(12,10))
data["Sub-Category"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
print(data['Sub-Category'].value_counts())
plt.figure(figsize=(12,6))
sns.countplot(x=data['Sub-Category'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
# Visualization

plt.figure(figsize=(15,8))
plt.bar('Sub-Category','Category',data=data)
plt.title("Sub Category vs Category")
plt.show()

# %%
x = sns.catplot(x="Sales",y="Sub-Category",col="Category",data=category_group,kind='bar')

# %%
y = sns.catplot(x="Quantity",y="Sub-Category",col="Category",data=category_group,kind='bar')

# %%
z = sns.catplot(x="Profit",y="Sub-Category",col="Category",data=category_group,kind='bar')

# %% [markdown]
# 1. In Technology category:
#     - copiers and machines are sold most, copiers provide more profit among all others. Sales are more than other two category.
# 2. In office supplies category:
#     - very minimal profit in all sub categories.
# 3. In Furniture category:
#     - Tables and bookcases are incuring lose.

# %% [markdown]
# ### Segment Wise

# %%
# Segments

data["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
sns.countplot(x=data['Segment'])

# %%
x = sns.catplot(x="Segment", y="Sales", data=segment_group, kind='bar')
for ax in x.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Segment-Wise Sales Done", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Segment-Wise Sales Done')

# %%
y = sns.catplot(x="Segment", y="Quantity", data=segment_group, kind='bar')
for ax in y.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Segment-Wise Quantity Sold", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Segment-Wise Quantity Sold')

# %%
z = sns.catplot(x="Segment", y="Profit", data=segment_group, kind='bar')
for ax in z.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Segment-Wise Profit Gained", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Segment-Wise Profit Gained')

# %% [markdown]
# From the above graph:
#
# - All types of Segments have shown almost same number of sales and same number of quantity sold.
#   Profit gained in the Home Office segment is higher comparing other two segments.

# %% [markdown]
# ### Region Wise

# %%
# Types of Regions

data["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
sns.countplot(x=data["Region"])

# %%
fig = plt.figure(figsize=(14,7))
a = sns.catplot(x='Region',
                y='Sales',
                data=data,
                kind='bar')
for ax in a.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Region-Wise Sales Done", fontsize=20)
plt.show()

# %%
b = sns.catplot(x='Region',
                y='Quantity',
                data=data,
                kind='bar')
for ax in b.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Region-Wise Quantity Sold", fontsize=20)
plt.show()

# %%
c = sns.catplot(x='Region',
                y='Profit',
                data=data,
                kind='bar')
for ax in c.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Region-Wise Profit Gained", fontsize=20)
plt.show()

# %% [markdown]
# From above graphs,
#
# - Sales are more in Southern and Eastern part of US.
# - Quantity of products sold in all the regions are almost same.
# - Profit gained in Western part of US is comparatively higher than other part.

# %% [markdown]
# ### State wise

# %%
state_code={""}

# %%
sales = state_group.sort_values(['Sales'], 
                                        ascending=False)[:10]
quantity = state_group.sort_values(['Quantity'], 
                                        ascending=False)[:10]
profit = state_group.sort_values(['Profit'], 
                                        ascending=False)[:10]

# %%
sales_values = sales.Sales
quantity_values = quantity.Quantity
profit_values = profit.Profit

sales_labels = sales.State
quantity_labels = quantity.State
profit_labels = profit.State

# %%
plt.pie(sales_values, labels=sales_labels, autopct='%1.f%%')
plt.title("Top 10 State in US with Highest Sales", fontsize=20)
plt.show()

# %%
plt.pie(quantity_values, labels=quantity_labels, autopct='%1.f%%')
plt.title("Top 10 State in US with Highest Quantity Sold", fontsize=20)
plt.show()

# %%
plt.pie(profit_values, labels=profit_labels, autopct='%1.f%%')
plt.title("Top 10 State in US with Highest Profit Gained", fontsize=20)
plt.show()

# %% [markdown]
# From these graphs, we can conclude that
#
# 1. Highest sale:
#     - Wyoming sales are highest among all.
# 2. Highest quantity sold:
#     - Almost all top 10 states have same quantity sold.
# 3. Highest profit gained:
#     - Vermont State gained the highest profit among all.

# %% [markdown]
# ### Ship mode wise

# %%
# Types of Ship modes

data["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
x = sns.catplot(x="Ship Mode", y="Sales", data=shipmode_group, kind='bar')
for ax in x.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Ship Mode-Wise Sales Done", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Ship Mode-Wise Sales Done')

# %%
y = sns.catplot(x="Ship Mode", y="Quantity", data=shipmode_group, kind='bar')
for ax in y.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Ship Mode-Wise Quantity Sold", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Ship Mode-Wise Quantity Sold')

# %%
z = sns.catplot(x="Ship Mode", y="Profit", data=shipmode_group, kind='bar')
for ax in z.axes.ravel():
  for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', xytext = (0, -100), 
                textcoords = 'offset points')
plt.title("Ship Mode-Wise Profit Gained", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Ship Mode-Wise Profit Gained')

# %% [markdown]
# From the above graph, all the ship mode show the almost same value. The ship mode  doesn't affect the Profit, Sales and Quantity.

# %% [markdown]
# ## Thank You
